# %%
import pandas as pd
import json
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=Service(service = Service("e:\software\chromedriver-win64")), options=options)
# Out:
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\Laiba Aslam\AppData\Local\Temp\ipykernel_4132\1070611183.py:12: SyntaxWarning: invalid escape sequence '\s'
#   driver = webdriver.Chrome(service=Service(service = Service("e:\software\chromedriver-win64")), options=options)

# %%
url = 'https://www.flipkart.com/'

driver.get(url)
driver.implicitly_wait(5)

# %%
import pandas as pd
df = pd.read_csv(r'E:\Post ADP\Capstone Project\FYP\datasets\product_links\flipkart_kids_furniture.csv')

links = df['0']
print(len(links))
# Out:
# 675

# %%
# data = []
# with open(r'E:\Post ADP\Capstone Project\FYP\datasets\reviews_dataset\kids_furniture_flipkart.json', 'w') as f:
#     json.dump(data, f, indent=4)

# %%
product_price = ''
product_description = ''
product_features = ''
product_image = ''
reviewer_ID = ''
reviewer_helpful_vote = '0'
reviewer_name = ''
review_title = ''
review_text=''
location=''
review_date=''
verified_purchase=''
review_rating='0'
review_helpful_vote='0'
product_categories = ''
total_rating= 0

# %%
import json
with open(r'E:\Post ADP\Capstone Project\FYP\datasets\reviews_dataset\kids_furniture_flipkart.json', 'r') as file:
    total_product_details = json.load(file)  # array for storing complete detail of all products
for i, link in enumerate(links):
    if i > 69 and i < len(links):
        driver.get(link)
        time.sleep(2)
        product_url = driver.current_url
        if product_url:
            Product_ID = product_url.split("pid=")[1].split('&')[0]
        try:
            product_title = driver.find_element(By.CSS_SELECTOR, ".VU-ZEz").text
        except:
            print("title not found")
        try:
            # Check if the element exists
            product_description_elements = driver.find_elements(By.XPATH, '//*[@id="container"]/div/div[3]/div[1]/div[2]/div[9]/div[2]/div/div[2]/div[1]')
            
            if product_description_elements:
                product_description = product_description_elements[0].text
                print(product_description)
            else:
                # Try the second XPath
                product_description_elements = driver.find_elements(By.XPATH, '//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[2]')
                if product_description_elements:
                    product_description = product_description_elements.text
                    print(product_description)
        except:
            print("product description not found")
        try:
            product_categories = driver.find_element(By.CSS_SELECTOR, "#container > div > div._39kFie.N3De93.JxFEK3._48O0EI > div.DOjaWF.YJG4Cf > div.DOjaWF.gdgoEp.col-8-12 > div:nth-child(1) > div:nth-child(1) > div > div:nth-child(3) > a").text
        except:
            print("Product categories not found")
        try:
            click_on_show_more = driver.find_element(By.CSS_SELECTOR, '.QqFHMw._4FgsLt')
            click_on_show_more.click()
            product_features = driver.find_element(By.CSS_SELECTOR, '._1OjC5I').text
        except:
            print("product features not found")
        try:
            product_price = driver.find_element(By.CSS_SELECTOR, ".Nx9bqj.CxhGGd").text
            product_price = product_price.replace("₹", "").strip()
            print(product_price)
        except:
            print("product price not found")
        try:
            product_image = driver.find_element(By.CSS_SELECTOR,".DByuf4.IZexXJ.jLEJ7H")
            product_image = product_image.get_attribute("src")
        except:
            print("product image not found")
        try:
            Brand_name = driver.find_element(By.CSS_SELECTOR, "#sellerName > span > span").text
            # Brand_name = Brand_name.find_element(By.CSS_SELECTOR, '.a-span9').text
        except:
            print("Brand name not found")
        try:
            avg_product_rating = driver.find_element(By.CSS_SELECTOR,".XQDdHH",).text
        except:
            print("average product rating not found")
        try:
            total_rating = driver.find_element(By.XPATH, "/html/body/div[1]/div/div[3]/div[1]/div[2]/div[2]/div/div[2]/div/div/span[2]/span/span[1]",).text
            print(f"total rating: {total_rating}")
            if total_rating:
                total_rating = ''.join(total_rating.split(' ')[0].split(','))
            else:
                print("not found")

            print(f"total rating: {total_rating}")
        except:
            print("total rating not found")
        # click on more reviews link for accessing all reviews of a product
        try:
            click_on_more_reviews = driver.find_element(By.CSS_SELECTOR, '._23J90q.RcXBOT')
            click_on_more_reviews.click()
            time.sleep(2)
        except:
            print("more review link not found")
        # found_reviews = 0
        # counter = 1
        while True:                                                        
            
            for j in range(4, 13):
                review_helpful_vote = '0'
                try:
                    reviews_div = driver.find_elements(By.CSS_SELECTOR, f'#container > div > div.VLIitu > div > div.DOjaWF.YJG4Cf.col-12-12 > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div')

                    time.sleep(2)
                except:
                    print("review div not found")
                    break
                try:
                    reviewer_name = driver.find_element(By.CSS_SELECTOR, f"#container > div > div.VLIitu > div > div.DOjaWF.YJG4Cf.col-12-12 > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div > div.row.gHqwa8 > div.row > p._2NsDsF.AwS1CA").text
                except:                                                    
                    print("Reviewer name not found")
                try:
                    review_title = driver.find_element(By.CSS_SELECTOR, f"#container > div > div.VLIitu > div > div > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div > div:nth-child(1) > p",).text
                except:
                    print("review_title not found")
                try:
                    review_text = driver.find_element(By.CSS_SELECTOR, f"#container > div > div.VLIitu > div > div.DOjaWF.YJG4Cf.col-12-12 > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div > div:nth-child(2) > div > div > div",).text
                except:
                    print("review text not found")
                try:
                    review_date = driver.find_element(By.CSS_SELECTOR, f'#container > div > div.VLIitu > div > div.DOjaWF.YJG4Cf.col-12-12 > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div > div.row.gHqwa8 > div.row > p:nth-child(5)').text
                    # print("review date: ", review_date)
                except:
                    print("date not found")
                
                try:
                    try:
                        verified_purchase_element = driver.find_element(
                            By.XPATH, f"/html/body/div/div/div[3]/div/div[1]/div[2]/div[{j}]/div/div/div/div[3]/div[1]/p[2]"
                        )
                        verified_purchase = verified_purchase_element.text
                        parts = verified_purchase.split(", ")
                        verified_purchase = parts[0]  # "Certified Buyer"
                        location = parts[1] 
                        print(f"Location: {location}")
                        print(f"Verified purchase (path 1): {verified_purchase}")
                    except:
                        # If the first XPath fails, try the second XPath
                        try:
                            verified_purchase_element = driver.find_element(
                                By.XPATH, f"/html/body/div/div/div[3]/div/div[1]/div[2]/div[{j}]/div/div/div/div[4]/div[1]/p[2]"
                            )
                            verified_purchase = verified_purchase_element.text
                            parts = verified_purchase.split(", ")
                            verified_purchase = parts[0]  # "Certified Buyer"
                            location = parts[1] 
                            print(f"Location: {location}")
                            print(f"Verified purchase (path 2): {verified_purchase}")
                        except:
                            # If neither XPath works, print a message
                            print("Verified purchase not found")
                except:
                    print("====verified purchase not found====")
                try:
                    review_rating = driver.find_element(By.CSS_SELECTOR, f"#container > div > div.VLIitu > div > div.DOjaWF.YJG4Cf.col-12-12 > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div > div:nth-child(1) > div").text
                    # review_rating=review_rating.split[0]
                    print("review_rating: ", review_rating)
                except:
                    print("review rating not found")
                try:
                    review_helpful_vote = driver.find_element(By.CSS_SELECTOR,f"#container > div > div.VLIitu > div > div.DOjaWF.YJG4Cf.col-12-12 > div.DOjaWF.gdgoEp.col-9-12 > div:nth-child({j}) > div > div > div > div.row.gHqwa8 > div.vMTK1V > div > div.qhmk-f > div:nth-child(1) > span",).text 
                    # print("review helpful vote: ", review_helpful_vote)
                except:
                    print("review helpful vote not found")
                scrapedInfo = {
                    "productTitle": product_title if isinstance(product_title, str) else '',
                    "ASIN": Product_ID if isinstance(Product_ID, str) else '',
                    "Price": product_price if isinstance(product_price, str) else '',
                    "Category": product_categories if isinstance(product_categories, str) else '',
                    "Features": product_features if isinstance(product_features, str) else '',
                    "Product Image": product_image if isinstance(product_image, str) else '',
                    "Brand Name": Brand_name if isinstance(Brand_name, str) else '',
                    "Total Rating": int(total_rating) if isinstance(total_rating, str) else 0,
                    "Average Rating": float(avg_product_rating) if isinstance(avg_product_rating, str) else 0.0,
                    "Description": product_description if isinstance(product_description, str) else '',
                    # "Reviewer ID": reviewer_ID if isinstance(reviewer_ID, str) else '',
                    "Reviewer Name": reviewer_name if isinstance(reviewer_name, str) else '',
                    # "Reviewer HelpfulVote": reviewer_helpful_vote,
                    "Review Title": review_title if isinstance(review_title, str) else '',
                    "Review Text": review_text if isinstance(review_text, str) else '',
                    "Location": location if isinstance(location, str) else '',
                    "Review Date": review_date if isinstance(review_date, str) else '',
                    "Verified Purchase": True if verified_purchase == "Certified Buyer" else False,
                    "Review Rating": float(review_rating) if isinstance(review_rating, str) else 0.0,
                    "Review helpful vote": int(review_helpful_vote)
                }
                # print(scrapedInfo)
                total_product_details.append(scrapedInfo)
                print('after creating object')
            try:
                # Wait until the "Next" anchor tag is available
                next_anchor = driver.find_element(By.XPATH, "//a[@class='_9QVEpD' and span='Next']")
                
                # Get the 'href' attribute of the anchor tag
                next_href = next_anchor.get_attribute('href')
                print(f"Next page link: {next_href}")
                
                # Optionally navigate to the next page
                driver.get(next_href)
                time.sleep(2)

            except:
                print(f"Error locating the 'Next' anchor tag")
                break
        print("=====================")
        with open(r'E:\Post ADP\Capstone Project\FYP\datasets\reviews_dataset\kids_furniture_flipkart.json', 'w') as json_file:
            json.dump(total_product_details, json_file, indent=4)
        print(len(total_product_details))
        print("=====================")
        # for j in range(counter):
        #     driver.back()
        #     time.sleep(2)
        print(f"{i} ====== links done =========")
# Out:
# 12,750
# total rating: 486 Ratings
# total rating 1: 486
# Location: Coimbatore
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Mananthavady
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Thrissur
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Chittorgarh
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: Hosur
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: New Delhi
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Ghaziabad
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=2
# Location: Mangaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Mumbai
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kannauj
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bareilly
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Visakhapatnam
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Chennai
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Seoni District
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=3
# Location: Bengaluru
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Pune
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bengaluru
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Shillong
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Gurgaon
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Sirgitti
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Vaniyanbadi
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Thanjavur
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=4
# Location: Chennai
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kozhikode
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Raipur
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Gurugram
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Tirupur
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Nilokheri
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kollam
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Rourkela
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=5
# Location: Itarsi
# Verified purchase (path 2): Certified Buyer
# review_rating:  3
# after creating object
# Location: Sirsi
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Krishnagiri
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bengaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hosur
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Chennai
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bangalore
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: New Delhi
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=6
# Location: Villupuram
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Puducherry
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Noida
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Baran
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Vadodara
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Yupia
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Silchar
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=7
# Location: Pune
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Thanjavur
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Gurugram
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: New Delhi
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Howrah
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bengaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kottayam District
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/steelwell-sigma-bunk-bed-junior-adult-guard-rail-space-saving-noise-free-metal/product-reviews/itm9fae0f9baf46a?pid=BKLGBCZNF53EPYPV&lid=LSTBKLGBCZNF53EPYPVXUGQWZ&marketplace=FLIPKART&page=8
# Location: Surat
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Siliguri
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: Raigarh District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bengaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Kottayam District
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Mumbai
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Bengaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Chennai
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Error locating the 'Next' anchor tag
# =====================
# 2917
# =====================
# 70 ====== links done =========
# 416
# total rating: 10,238 Ratings
# total rating 1: 10238
# Location: Lalpet
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kodarma
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: Bengaluru
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: Hutmura
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Ahmed Nagar
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Muzaffarpur
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kharupatia
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Palwal
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Kalaburgi
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=2
# Location: Mumbai
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Nagpur
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: East Godavari District
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: Purba Champaran District
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Location: New Delhi
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Nandigama
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Rajahmundry
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Prakasam District
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Puliyur
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=3
# Location: Visakhapatnam
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Chennai
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bhubaneswar
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Jallaram
# Verified purchase (path 2): Certified Buyer
# review_rating:  3
# after creating object
# Location: Coimbatore
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Karur
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Mangaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Aligarh
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Bhopal
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=4
# Location: Nagercoil
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Madurai
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Guwahati
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Vadodara
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hugli District
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Tirupathur District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: B Mallapuram
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Erode
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kalna
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=5
# Location: Jamshedpur
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Rajkot
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Chennai
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Madurai
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Azamgarh District
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Tarakeswar
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Karur
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Pathsala
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Brajarajnagar
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=6
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Tumkur District
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Howrah
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Kurnool
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Pune
# Verified purchase (path 1): Certified Buyer
# review_rating:  2
# after creating object
# Location: Barahiya
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Chennai
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Jamnagar District
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: North Twenty Four Parganas District
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=7
# Location: Cherppulassery
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Purba Bardhaman District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Ghaziabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Berhampore
# Verified purchase (path 1): Certified Buyer
# review_rating:  2
# after creating object
# Location: Purba Bardhaman District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Namakkal District
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Hugli District
# Verified purchase (path 1): Certified Buyer
# review_rating:  2
# after creating object
# Location: Riico Industrial Area Neemrana
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Sindhnur
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=8
# Location: Ahmadnagar District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hindupur
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kancheepuram
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Dhule
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Gaya
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Chinhat
# Verified purchase (path 2): Certified Buyer
# review_rating:  1
# after creating object
# Location: Bokajan
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Aluva
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Cheeka
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=9
# Location: Ganjam District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Chennai
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Periapattinam
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Periapattinam
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kurasia
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Pandamangalam
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Narwana
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Kheri District
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Cuttack
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=10
# Location: Murshidabad District
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Bilaspur District
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Raigarh District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Jajapur District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Anand District
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: Bilaspur
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Navi Mumbai
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Next page link: https://www.flipkart.com/hariom-all-one-study-table-laptop-engineered-wood/product-reviews/itm02d96967967fc?pid=KDTG8X66GUZCWHXT&lid=LSTKDTG8X66GUZCWHXT9GFVHS&marketplace=FLIPKART&page=11
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found
# review helpful vote not found
# after creating object
# Error locating the 'Next' anchor tag
# =====================
# 3016
# =====================
# 71 ====== links done =========
# 2,826
# total rating: 260 Ratings
# total rating 1: 260
# Location: Greater Noida
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Dharuhera
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kumta
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Bengaluru
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Kanchipuram
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Location: New Delhi
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Asaripallam
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Malappuram
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Agra
# Verified purchase (path 2): Certified Buyer
# review_rating:  4
# after creating object
# Next page link: https://www.flipkart.com/my-little-town-kids-study-table-chair-adjustable-height-green-engineered-wood/product-reviews/itmfd36a3802b5bc?pid=KDTGZZQFT8Z5BWRW&lid=LSTKDTGZZQFT8Z5BWRWQO7KDK&marketplace=FLIPKART&page=2
# Location: Visakhapatnam
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Tiruppur
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Bisauli
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Lucknow
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Thiruvananthapuram
# Verified purchase (path 1): Certified Buyer
# review_rating:  3
# after creating object
# Location: Ongole
# Verified purchase (path 2): Certified Buyer
# review_rating:  5
# after creating object
# Location: Hyderabad
# Verified purchase (path 1): Certified Buyer
# review_rating:  4
# after creating object
# Location: Ballari
# Verified purchase (path 1): Certified Buyer
# review_rating:  1
# after creating object
# Next page link: https://www.flipkart.com/my-little-town-kids-study-table-chair-adjustable-height-green-engineered-wood/product-reviews/itmfd36a3802b5bc?pid=KDTGZZQFT8Z5BWRW&lid=LSTKDTGZZQFT8Z5BWRWQO7KDK&marketplace=FLIPKART&page=3
# Location: Koppal
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Dibiyapur
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Location: Aligarh
# Verified purchase (path 1): Certified Buyer
# review_rating:  5
# after creating object
# Reviewer name not found
# review_title not found
# review text not found
# date not found
# Verified purchase not found
# review rating not found

# %%
import json
print("=====================")
with open('reviews.json', 'w') as json_file:
    json.dump(total_product_details, json_file, indent=4)
print(len(total_product_details))
print("=====================")
# Out:
# =====================
# 8379
# =====================

# %%
reviewer_helpful_vote
# Out:
# '0'

# %%
len = len(total_product_details)
len
# Out:
# 8379

# %%
import pandas as pd 
df = pd.DataFrame(total_product_details)
df
# Out:
#                                            productTitle              ASIN  \
# 0     Primebook Wifi MediaTek MT8183 - (4 GB/64 GB E...  COMGT846VD2DQBG4
# 1     Primebook Wifi MediaTek MT8183 - (4 GB/64 GB E...  COMGT846VD2DQBG4
# 2     Primebook Wifi MediaTek MT8183 - (4 GB/64 GB E...  COMGT846VD2DQBG4
# 3     Primebook Wifi MediaTek MT8183 - (4 GB/64 GB E...  COMGT846VD2DQBG4
# 4     Primebook Wifi MediaTek MT8183 - (4 GB/64 GB E...  COMGT846VD2DQBG4
# ...                                                 ...               ...
# 8374  HP HP Envy AMD Ryzen 7 Octa Core 4700U - (16 G...  COMG5VYYFDGESDYZ
# 8375  HP HP Envy AMD Ryzen 7 Octa Core 4700U - (16 G...  COMG5VYYFDGESDYZ
# 8376  HP HP Envy AMD Ryzen 7 Octa Core 4700U - (16 G...  COMG5VYYFDGESDYZ
# 8377  HP HP Envy AMD Ryzen 7 Octa Core 4700U - (16 G...  COMG5VYYFDGESDYZ
# 8378  HP HP Envy AMD Ryzen 7 Octa Core 4700U - (16 G...  COMG5VYYFDGESDYZ
#
#        Price Category                                           Features  \
# 0     10,990  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 1     10,990  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 2     10,990  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 3     10,990  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 4     10,990  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# ...      ...      ...                                                ...
# 8374  93,000  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 8375  93,000  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 8376  93,000  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 8377  93,000  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
# 8378  93,000  Laptops  General\nSales Package\nLaptop, Power Adaptor,...
#
#                                           Product Image    Brand Name  \
# 0     https://rukminim2.flixcart.com/image/416/416/x...     RetailNet
# 1     https://rukminim2.flixcart.com/image/416/416/x...     RetailNet
# 2     https://rukminim2.flixcart.com/image/416/416/x...     RetailNet
# 3     https://rukminim2.flixcart.com/image/416/416/x...     RetailNet
# 4     https://rukminim2.flixcart.com/image/416/416/x...     RetailNet
# ...                                                 ...           ...
# 8374  https://rukminim2.flixcart.com/image/416/416/k...  HIYAINFOTECH
# 8375  https://rukminim2.flixcart.com/image/416/416/k...  HIYAINFOTECH
# 8376  https://rukminim2.flixcart.com/image/416/416/k...  HIYAINFOTECH
# 8377  https://rukminim2.flixcart.com/image/416/416/k...  HIYAINFOTECH
# 8378  https://rukminim2.flixcart.com/image/416/416/k...  HIYAINFOTECH
#
#       Total Rating  Average Rating  \
# 0             2778             4.2
# 1             2778             4.2
# 2             2778             4.2
# 3             2778             4.2
# 4             2778             4.2
# ...            ...             ...
# 8374            11             4.4
# 8375            11             4.4
# 8376            11             4.4
# 8377            11             4.4
# 8378            11             4.4
#
#                                             Description      Reviewer Name  \
# 0     Primebook Wifi is more than just a laptop; it'...  Flipkart Customer
# 1     Primebook Wifi is more than just a laptop; it'...         Bikash Dey
# 2     Primebook Wifi is more than just a laptop; it'...  Flipkart Customer
# 3     Primebook Wifi is more than just a laptop; it'...     Sikandar Kumar
# 4     Primebook Wifi is more than just a laptop; it'...  Flipkart Customer
# ...                                                 ...                ...
# 8374
# 8375
# 8376
# 8377
# 8378
#
#         Review Title                                        Review Text  \
# 0     Simply awesome                                   Good For student
# 1           Terrific                                    Value for money
# 2          Must buy!                                  Very good product
# 3             Super!  Oustanding product I love ❤this product..... S...
# 4          Fabulous!                   This item very useful amazing 🤩🤩
# ...              ...                                                ...
# 8374
# 8375
# 8376
# 8377
# 8378
#
#               Location Review Date  Verified Purchase  Review Rating  \
# 0     Neemuch District   Oct, 2023               True            5.0
# 1           Jamshedpur   Oct, 2023               True            5.0
# 2              Khammam   Oct, 2023               True            5.0
# 3              Kolkata   Oct, 2023               True            5.0
# 4              Bemetra   Oct, 2023               True            5.0
# ...                ...         ...                ...            ...
# 8374                                            False            0.0
# 8375                                            False            0.0
# 8376                                            False            0.0
# 8377                                            False            0.0
# 8378                                            False            0.0
#
#       Review helpful vote
# 0                     292
# 1                     216
# 2                      18
# 3                      87
# 4                      70
# ...                   ...
# 8374                    0
# 8375                    0
# 8376                    0
# 8377                    0
# 8378                    0
#
# [8379 rows x 18 columns]

# %%
df.to_csv(r'E:\Post ADP\Post ADP 3\Capstone Project\Scrapping from Amazon\product_reviews_details.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.to_csv(r'E:\Post ADP\Post ADP 3\Capstone Project\Scrapping from Amazon\product_reviews_details.csv', index=False)
#
# File c:\Python312\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Python312\Lib\site-packages\pandas\core\generic.py:3967, in NDFrame.to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3956 df = self if isinstance(self, ABCDataFrame) else self.to_frame()
#    3958 formatter = DataFrameFormatter(
#    3959     frame=df,
#    3960     header=header,
#    (...)
#    3964     decimal=decimal,
#    3965 )
# -> 3967 return DataFrameRenderer(formatter).to_csv(
#    3968     path_or_buf,
#    3969     lineterminator=lineterminator,
#    3970     sep=sep,
#    3971     encoding=encoding,
#    3972     errors=errors,
#    3973     compression=compression,
#    3974     quoting=quoting,
#    3975     columns=columns,
#    3976     index_label=index_label,
#    3977     mode=mode,
#    3978     chunksize=chunksize,
#    3979     quotechar=quotechar,
#    3980     date_format=date_format,
#    3981     doublequote=doublequote,
#    3982     escapechar=escapechar,
#    3983     storage_options=storage_options,
#    3984 )
#
# File c:\Python312\Lib\site-packages\pandas\io\formats\format.py:1014, in DataFrameRenderer.to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, lineterminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#     993     created_buffer = False
#     995 csv_formatter = CSVFormatter(
#     996     path_or_buf=path_or_buf,
#     997     lineterminator=lineterminator,
#    (...)
#    1012     formatter=self.fmt,
#    1013 )
# -> 1014 csv_formatter.save()
#    1016 if created_buffer:
#    1017     assert isinstance(path_or_buf, StringIO)
#
# File c:\Python312\Lib\site-packages\pandas\io\formats\csvs.py:251, in CSVFormatter.save(self)
#     247 """
#     248 Create the writer & save.
#     249 """
#     250 # apply compression and byte/text conversion
# --> 251 with get_handle(
#     252     self.filepath_or_buffer,
#     253     self.mode,
#     254     encoding=self.encoding,
#     255     errors=self.errors,
#     256     compression=self.compression,
#     257     storage_options=self.storage_options,
#     258 ) as handles:
#     259     # Note: self.encoding is irrelevant here
#     260     self.writer = csvlib.writer(
#     261         handles.handle,
#     262         lineterminator=self.lineterminator,
#    (...)
#     267         quotechar=self.quotechar,
#     268     )
#     270     self._save()
#
# File c:\Python312\Lib\site-packages\pandas\io\common.py:749, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     747 # Only for write methods
#     748 if "r" not in mode and is_path:
# --> 749     check_parent_directory(str(handle))
#     751 if compression:
#     752     if compression != "zstd":
#     753         # compression libraries do not like an explicit text-mode
#
# File c:\Python312\Lib\site-packages\pandas\io\common.py:616, in check_parent_directory(path)
#     614 parent = Path(path).parent
#     615 if not parent.is_dir():
# --> 616     raise OSError(rf"Cannot save file into a non-existent directory: '{parent}'")
#
# OSError: Cannot save file into a non-existent directory: 'E:\Post ADP\Post ADP 3\Capstone Project\Scrapping from Amazon'

# %%
import json
import csv

# %%
data = []

# Specify the encoding while opening the file
with open(r'e:\Post ADP\Post ADP 3\Capstone Project\Scrapping from Amazon\reviews.csv', 'r', encoding='utf-8') as f:
    csvFile = csv.DictReader(f)

    for row in csvFile:
        data.append(row)

# Write the data to a JSON file
with open(r'e:\Post ADP\Post ADP 3\Capstone Project\Scrapping from Amazon\reviews.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, indent=4)

print("CSV data has been successfully converted to JSON and saved.")

# %%
import os
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Connect to the MongoDB server
client = MongoClient("mongodb://localhost:27017/", server_api=ServerApi('1'))

# Create or connect to a database
db = client["FYP_Data"]

# Create or connect to a collection
collection = db["Product Details"]

with open(r'e:\Post ADP\Post ADP 3\Capstone Project\Scrapping from Amazon\reviews.json', 'r') as f:
    data = json.load(f)


    collection.insert_many(data)

# %%
/html/body/div/div/div[3]/div/div[1]/div[2]/div[3]/div/div/div/div[3]/div[1]/p[2]
/html/body/div/div/div[3]/div/div[1]/div[2]/div[4]/div/div/div/div[4]/div[1]/p[2]
/html/body/div/div/div[3]/div/div[1]/div[2]/div[5]/div/div/div/div[3]/div[1]/p[2]
/html/body/div/div/div[3]/div/div[1]/div[2]/div[6]/div/div/div/div[4]/div[1]/p[2]
/html/body/div/div/div[3]/div/div[1]/div[2]/div[7]/div/div/div/div[3]/div[1]/p[2]
